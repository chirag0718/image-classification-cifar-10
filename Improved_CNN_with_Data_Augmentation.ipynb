# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras import datasets
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, MaxPooling2D,Dropout, BatchNormalization
import random
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %%
def preProcessing(cifar_dataset):
    # Downloading the dataset
    (X_train, y_train), (X_test, y_test) = cifar_dataset

    # Normalize pixel the value between 1 and 0
    X_train, X_test = X_train / 255.0, X_test / 255.0

    # one hot encoding or format accepted by tensorflow - vector structure.
    y_train, y_test = y_train.flatten(), y_test.flatten()

    # Printing the X_train and y_train
    print("X_train shape", X_train.shape)
    print("y_train shape", y_train.shape)

    return X_train, y_train, X_test, y_test

# %%
# Generate 10 random images through X_train and y_train data for ten classes
def displayTenRandomImages(images, labels):
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
    temp = class_names.copy()
    plt.figure(figsize=(10,10))
    j = 0
    while len(temp) > 0:
        index = random.randint(0,len(labels))
        class_name = class_names[(labels[index])]
        if temp and class_name in temp:
            plt.subplot(5,5,j+1)
            plt.xticks([])
            plt.yticks([])
            plt.grid(False)
            plt.imshow(images[index])
            plt.xlabel(class_names[labels[index]])
            temp.remove(class_name)
            j += 1
            
    plt.show()

# %%
def improved_cnn_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', padding="same" , input_shape=(32, 32, 3)),
        BatchNormalization(),
        Conv2D(32, (3, 3), activation='relu', padding="same"),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.2),
        Conv2D(64, (3,3), activation='relu', padding="same"),
        BatchNormalization(),
        Conv2D(64, (3,3), activation='relu', padding="same"),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.2),
        Conv2D(128, (3, 3), activation='relu', padding="same"),
        BatchNormalization(),
        Conv2D(128, (3, 3), activation='relu', padding="same"),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.2),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.2),
        Dense(10, activation="softmax") # Number of classes
    ])

    model.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                metrics=['accuracy'])

    return model

# %%
def model_summary(result):
    # Displaying Loss and Accuracy
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(result.history['loss'], label='loss')
    plt.plot(result.history['val_loss'], label='val_loss')
    plt.title('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(result.history['accuracy'], label='accuracy')
    plt.plot(result.history['val_accuracy'], label='val_accuracy')
    plt.title('Accuracy')
    plt.legend()

# %%
def run_model():
    
    # Loading and pre processing data
    X_train, y_train, X_test, y_test = preProcessing(datasets.cifar10.load_data())
    
    # Display ten random images
    displayTenRandomImages(X_train, y_train)

    # Loading model
    model = improved_cnn_model()

    # Early Stopping with patience 10
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

    # model fit
    datagen = ImageDataGenerator(
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        )

    result = model.fit(datagen.flow(X_train, y_train, batch_size = 32),
                    steps_per_epoch = X_train.shape[0] / 32, # number of samples per gradient update
                    epochs = 100, # number of iterations
                    validation_data= (X_test, y_test), callbacks=[callback], verbose=2)
    
    # Displaying accuracy and loss
    model_summary(result)

    # Evaluate model
    test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
    print(test_acc)
    
    # Save model
    model.save('data_augmentation_dropout_batch_normalization_final_model.h5')

# %%
run_model()
# Out:
# X_train shape (50000, 32, 32, 3)
# y_train shape (50000,)
# Epoch 1/100
# 1562/1562 - 57s - loss: 1.5101 - accuracy: 0.4712 - val_loss: 1.1080 - val_accuracy: 0.6042 - 57s/epoch - 37ms/step
# Epoch 2/100
# 1562/1562 - 47s - loss: 1.0749 - accuracy: 0.6239 - val_loss: 0.9909 - val_accuracy: 0.6569 - 47s/epoch - 30ms/step
# Epoch 3/100
# 1562/1562 - 47s - loss: 0.9160 - accuracy: 0.6824 - val_loss: 0.8622 - val_accuracy: 0.7082 - 47s/epoch - 30ms/step
# Epoch 4/100
# 1562/1562 - 46s - loss: 0.8199 - accuracy: 0.7170 - val_loss: 0.7451 - val_accuracy: 0.7499 - 46s/epoch - 30ms/step
# Epoch 5/100
# 1562/1562 - 47s - loss: 0.7523 - accuracy: 0.7426 - val_loss: 0.8154 - val_accuracy: 0.7429 - 47s/epoch - 30ms/step
# Epoch 6/100
# 1562/1562 - 46s - loss: 0.7007 - accuracy: 0.7592 - val_loss: 0.7097 - val_accuracy: 0.7573 - 46s/epoch - 30ms/step
# Epoch 7/100
# 1562/1562 - 47s - loss: 0.6570 - accuracy: 0.7753 - val_loss: 0.6655 - val_accuracy: 0.7854 - 47s/epoch - 30ms/step
# Epoch 8/100
# 1562/1562 - 48s - loss: 0.6250 - accuracy: 0.7872 - val_loss: 0.6271 - val_accuracy: 0.7916 - 48s/epoch - 31ms/step
# Epoch 9/100
# 1562/1562 - 48s - loss: 0.5968 - accuracy: 0.7971 - val_loss: 0.5540 - val_accuracy: 0.8185 - 48s/epoch - 31ms/step
# Epoch 10/100
# 1562/1562 - 46s - loss: 0.5656 - accuracy: 0.8088 - val_loss: 0.5324 - val_accuracy: 0.8249 - 46s/epoch - 30ms/step
# Epoch 11/100
# 1562/1562 - 46s - loss: 0.5349 - accuracy: 0.8179 - val_loss: 0.5311 - val_accuracy: 0.8222 - 46s/epoch - 30ms/step
# Epoch 12/100
# 1562/1562 - 46s - loss: 0.5158 - accuracy: 0.8240 - val_loss: 0.5214 - val_accuracy: 0.8248 - 46s/epoch - 29ms/step
# Epoch 13/100
# 1562/1562 - 46s - loss: 0.5025 - accuracy: 0.8292 - val_loss: 0.4967 - val_accuracy: 0.8316 - 46s/epoch - 30ms/step
# Epoch 14/100
# 1562/1562 - 46s - loss: 0.4856 - accuracy: 0.8348 - val_loss: 0.5364 - val_accuracy: 0.8235 - 46s/epoch - 29ms/step
# Epoch 15/100
# 1562/1562 - 46s - loss: 0.4606 - accuracy: 0.8426 - val_loss: 0.5533 - val_accuracy: 0.8224 - 46s/epoch - 29ms/step
# Epoch 16/100
# 1562/1562 - 46s - loss: 0.4473 - accuracy: 0.8478 - val_loss: 0.4991 - val_accuracy: 0.8359 - 46s/epoch - 30ms/step
# Epoch 17/100
# 1562/1562 - 46s - loss: 0.4320 - accuracy: 0.8499 - val_loss: 0.4721 - val_accuracy: 0.8459 - 46s/epoch - 29ms/step
# Epoch 18/100
# 1562/1562 - 46s - loss: 0.4172 - accuracy: 0.8572 - val_loss: 0.4706 - val_accuracy: 0.8457 - 46s/epoch - 29ms/step
# Epoch 19/100
# 1562/1562 - 45s - loss: 0.4111 - accuracy: 0.8600 - val_loss: 0.4387 - val_accuracy: 0.8548 - 45s/epoch - 29ms/step
# Epoch 20/100
# 1562/1562 - 46s - loss: 0.4017 - accuracy: 0.8620 - val_loss: 0.4196 - val_accuracy: 0.8596 - 46s/epoch - 30ms/step
# Epoch 21/100
# 1562/1562 - 46s - loss: 0.3867 - accuracy: 0.8668 - val_loss: 0.5151 - val_accuracy: 0.8365 - 46s/epoch - 30ms/step
# Epoch 22/100
# 1562/1562 - 46s - loss: 0.3846 - accuracy: 0.8668 - val_loss: 0.4430 - val_accuracy: 0.8490 - 46s/epoch - 29ms/step
# Epoch 23/100
# 1562/1562 - 46s - loss: 0.3736 - accuracy: 0.8712 - val_loss: 0.4152 - val_accuracy: 0.8656 - 46s/epoch - 29ms/step
# Epoch 24/100
# 1562/1562 - 46s - loss: 0.3644 - accuracy: 0.8753 - val_loss: 0.4345 - val_accuracy: 0.8533 - 46s/epoch - 30ms/step
# Epoch 25/100
# 1562/1562 - 46s - loss: 0.3531 - accuracy: 0.8767 - val_loss: 0.4441 - val_accuracy: 0.8607 - 46s/epoch - 29ms/step
# Epoch 26/100
# 1562/1562 - 46s - loss: 0.3546 - accuracy: 0.8787 - val_loss: 0.3901 - val_accuracy: 0.8687 - 46s/epoch - 29ms/step
# Epoch 27/100
# 1562/1562 - 45s - loss: 0.3405 - accuracy: 0.8827 - val_loss: 0.3843 - val_accuracy: 0.8714 - 45s/epoch - 29ms/step
# Epoch 28/100
# 1562/1562 - 46s - loss: 0.3336 - accuracy: 0.8851 - val_loss: 0.4180 - val_accuracy: 0.8690 - 46s/epoch - 29ms/step
# Epoch 29/100
# 1562/1562 - 45s - loss: 0.3301 - accuracy: 0.8858 - val_loss: 0.3835 - val_accuracy: 0.8745 - 45s/epoch - 29ms/step
# Epoch 30/100
# 1562/1562 - 46s - loss: 0.3305 - accuracy: 0.8867 - val_loss: 0.3958 - val_accuracy: 0.8691 - 46s/epoch - 29ms/step
# Epoch 31/100
# 1562/1562 - 46s - loss: 0.3142 - accuracy: 0.8918 - val_loss: 0.3935 - val_accuracy: 0.8705 - 46s/epoch - 29ms/step
# Epoch 32/100
# 1562/1562 - 46s - loss: 0.3148 - accuracy: 0.8913 - val_loss: 0.3998 - val_accuracy: 0.8690 - 46s/epoch - 29ms/step
# Epoch 33/100
# 1562/1562 - 46s - loss: 0.3051 - accuracy: 0.8942 - val_loss: 0.3825 - val_accuracy: 0.8738 - 46s/epoch - 29ms/step
# Epoch 34/100
# 1562/1562 - 46s - loss: 0.3018 - accuracy: 0.8943 - val_loss: 0.3936 - val_accuracy: 0.8754 - 46s/epoch - 29ms/step
# Epoch 35/100
# 1562/1562 - 45s - loss: 0.2987 - accuracy: 0.8972 - val_loss: 0.3755 - val_accuracy: 0.8799 - 45s/epoch - 29ms/step
# Epoch 36/100
# 1562/1562 - 45s - loss: 0.2985 - accuracy: 0.8964 - val_loss: 0.3687 - val_accuracy: 0.8810 - 45s/epoch - 29ms/step
# Epoch 37/100
# 1562/1562 - 46s - loss: 0.2897 - accuracy: 0.8994 - val_loss: 0.4002 - val_accuracy: 0.8717 - 46s/epoch - 29ms/step
# Epoch 38/100
# 1562/1562 - 46s - loss: 0.2870 - accuracy: 0.9007 - val_loss: 0.3710 - val_accuracy: 0.8780 - 46s/epoch - 29ms/step
# Epoch 39/100
# 1562/1562 - 46s - loss: 0.2833 - accuracy: 0.9036 - val_loss: 0.3905 - val_accuracy: 0.8761 - 46s/epoch - 29ms/step
# Epoch 40/100
# 1562/1562 - 46s - loss: 0.2809 - accuracy: 0.9036 - val_loss: 0.3884 - val_accuracy: 0.8789 - 46s/epoch - 29ms/step
# Epoch 41/100
# 1562/1562 - 46s - loss: 0.2751 - accuracy: 0.9057 - val_loss: 0.3941 - val_accuracy: 0.8731 - 46s/epoch - 30ms/step
# Epoch 42/100
# 1562/1562 - 46s - loss: 0.2751 - accuracy: 0.9060 - val_loss: 0.3945 - val_accuracy: 0.8759 - 46s/epoch - 29ms/step
# Epoch 43/100
# 1562/1562 - 46s - loss: 0.2685 - accuracy: 0.9067 - val_loss: 0.3887 - val_accuracy: 0.8749 - 46s/epoch - 29ms/step
# Epoch 44/100
# 1562/1562 - 46s - loss: 0.2667 - accuracy: 0.9072 - val_loss: 0.3806 - val_accuracy: 0.8830 - 46s/epoch - 29ms/step
# Epoch 45/100
# 1562/1562 - 46s - loss: 0.2625 - accuracy: 0.9084 - val_loss: 0.3999 - val_accuracy: 0.8758 - 46s/epoch - 29ms/step
# Epoch 46/100
# 1562/1562 - 46s - loss: 0.2581 - accuracy: 0.9109 - val_loss: 0.4266 - val_accuracy: 0.8672 - 46s/epoch - 29ms/step
# 313/313 - 2s - loss: 0.4266 - accuracy: 0.8672 - 2s/epoch - 7ms/step
# 0.8672000169754028

# %%
from keras.preprocessing import image
from keras.models import load_model
import numpy as np
from tensorflow.keras import datasets

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# Normalize pixel the value between 1 and 0
X_train, X_test = X_train / 255.0, X_test / 255.0

# one hot encoding or format accepted by tensorflow - vector structure.
y_train, y_test = y_train.flatten(), y_test.flatten()

model = load_model('drive/MyDrive/3014397_ITNPAI1/data_augmentation_dropout_batch_normalization_final_model.h5')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
result = model.predict(X_test)
y_prediction = np.argmax(result,axis=1)
y_prediction[:5]
# Out:
# array([3, 8, 8, 0, 6])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt 
cm = confusion_matrix(y_test,y_prediction)
plt.figure(figsize=(16,10))
sns.heatmap(cm, annot=True, fmt='.2f',  xticklabels=class_names, yticklabels = class_names)

# %%
from IPython.core.pylabtools import figsize
import random
def predict_and_plot():
    plt.figure(figsize=(12, 12))

    # Predicting the random images 
    for k in range(10):
        random_number = random.randint(0, len(X_test))
        img = (X_test[random_number].reshape(1, 32, 32, 3)).astype('float32')
        result = model.predict(img)
        class_num = np.argmax(result,axis=1)
        plt.subplot(5,5,k+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(X_test[random_number])
        plt.title(class_names[int(class_num)], fontsize=12)

predict_and_plot()
